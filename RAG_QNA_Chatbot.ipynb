# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# %%
# !pip install langchain langchain-huggingface sentence-transformers faiss-cpu transformers torch
# Out:
# Requirement already satisfied: langchain in c:\users\mugdhi saxena\anaconda3\lib\site-packages (0.2.14)
# Requirement already satisfied: langchain-huggingface in c:\users\mugdhi saxena\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: sentence-transformers in c:\users\mugdhi saxena\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: faiss-cpu in c:\users\mugdhi saxena\anaconda3\lib\site-packages (1.8.0.post1)
# Requirement already satisfied: transformers in c:\users\mugdhi saxena\anaconda3\lib\site-packages (4.44.0)
# Requirement already satisfied: torch in c:\users\mugdhi saxena\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (0.2.32)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (0.1.99)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-huggingface) (0.24.5)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-huggingface) (0.19.1)
# Requirement already satisfied: tqdm in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: scikit-learn in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from sentence-transformers) (1.11.1)
# Requirement already satisfied: Pillow in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: packaging in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: filelock in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from transformers) (0.4.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain) (2.1)

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\mugdhi saxena\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.2.32)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.1.99)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (1.24.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain_community) (1.10.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain_community) (2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings

# %%
import os
import sys
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.agents import initialize_agent, Tool, AgentType
from langchain.prompts import PromptTemplate
from langchain_community.llms import Ollama
from langchain_community.embeddings import OllamaEmbeddings
from langchain.docstore.document import Document
from langchain.docstore.in_memory import InMemoryDocstore

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\mugdhi saxena\anaconda3\lib\site-packages (4.3.1)

# %%
# Load the PDF document
pdf_path = r"iphone_manual.pdf"# Update this path
loader = PyPDFLoader(pdf_path)
documents = loader.load()

# %%
# Create a docstore
docstore = InMemoryDocstore({doc.metadata["source"]: doc for doc in documents})

# %%
# # Extract text and split into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)
chunks = text_splitter.split_documents(documents)

# %%
print(f"Number of chunks: {len(chunks)}")
print(f"First chunk: {chunks[0].page_content[:100]}...")
# Out:
# Number of chunks: 538
# First chunk: Before using iPhone, review the iPhone User Guide  at
# support.apple.com/en-gb/guide/iphone . You c...

# %%
# Model Availability Check
try:
    llm = Ollama(model="gemma2:2b")
    test_input = "What is the capital of Haryana?"
    test_output = llm.predict(test_input)
    print(f"Model test prediction: {test_output}")
except Exception as e:
    print(f"Error in loading or using the model: {e}")
# Out:
# C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The method `BaseLLM.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(
# Model test prediction: The capital of Haryana is **Chandigarh**.

# %%
# Vector Store and Embeddings Check
try:
    embed_model = OllamaEmbeddings(model="gemma2:2b") 
    vectorstore = FAISS.from_documents(chunks, embed_model)
    retriever = vectorstore.as_retriever()
    
    # Test retrieval with a sample query
    query = "What is the document about?"
    results = retriever.get_relevant_documents(query)  # Correct method for retrieval
    print(f"Vector store retrieval result: {results}")
except Exception as e:
    print(f"Error in creating or using vector store: {e}")
# Out:
# C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(
# Vector store retrieval result: [Document(metadata={'source': 'C:\\Users\\Mugdhi Saxena\\Documents\\Mugdhi S\\cognizant\\iphone_manual.pdf', 'page': 44}, page_content='Before using iPhone, review the iPhone User Guide  at support.apple.com/\nguide/iphone . You can also download the guide from Apple Books (where \navailable). Retain documentation for future reference.'), Document(metadata={'source': 'C:\\Users\\Mugdhi Saxena\\Documents\\Mugdhi S\\cognizant\\iphone_manual.pdf', 'page': 8}, page_content='“Important safety information” in the iPhone User Guide.'), Document(metadata={'source': 'C:\\Users\\Mugdhi Saxena\\Documents\\Mugdhi S\\cognizant\\iphone_manual.pdf', 'page': 20}, page_content='“Important safety information” in the iPhone User Guide.'), Document(metadata={'source': 'C:\\Users\\Mugdhi Saxena\\Documents\\Mugdhi S\\cognizant\\iphone_manual.pdf', 'page': 52}, page_content='“Important safety information” in the iPhone User Guide.')]

# %%
# QA Chain Check
try:
    prompt_template = PromptTemplate(
        input_variables=["context", "question"],
        template="Context: {context}\nQuestion: {question}\nAnswer:"
    )
    
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt_template}
    )
    
    test_context = "This is a test context to verify QA chain functionality."
    test_question = "What is this context about?"
    test_answer = qa_chain.run({"query": f"{test_context} {test_question}"})  # Combine context and question into one query
    print(f"QA chain test answer: {test_answer}")
    
except Exception as e:
    print(f"Error in creating or using QA chain: {e}")
    qa_chain = None  # Set qa_chain to None if there's an error
# Out:
# C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(
# QA chain test answer: This context is about **Apple's product warranties and environmental commitments**.
#
# Here's why:
#
# * **Warranty information:** The text provides links to Apple's warranty terms and support pages, indicating a focus on product usage and potential issues.
# * **Environmental initiatives:** Mentions of recycling programs, restricted substances, and other "environmental initiatives" suggest an emphasis on sustainability and the impact of technology on the environment.
#
# Therefore, this context aims to inform users about their product's legal protection and Apple's commitment towards environmentally responsible practices.

# %%
# Ensure the QA chain is defined before creating tools
tools = []
if qa_chain:
    tools = [
        Tool(
            name="PDF QA System",
            func=qa_chain.run,
            description="Useful for answering questions about the PDF document"
        ),
        Tool(
            name="Document Lookup",
            func=lambda x: docstore.search(x),
            description="Useful for looking up specific documents by source"
        )
    ]

# %%
try:
    if tools:  # Only proceed if tools are defined
        agent_prompt = """Answer the following question directly and concisely. If you need to use a tool, do so without explaining the process. Only provide the final answer.

        Question: {input}
        """
        agent = initialize_agent(
            tools, 
            llm, 
            agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
            verbose=False,  # Set to False to reduce output
            agent_kwargs={
                "prompt": PromptTemplate.from_template(agent_prompt),
                "max_iterations": 3  # Reduce max iterations for faster responses
            }
        )
except Exception as e:
    print(f"Error in initializing agent: {e}")
# Out:
# C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:141: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 1.0. Use Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc. instead.
#   warn_deprecated(

# %%
# Function to run the agent
def run_agent(user_input):
    try:
        # Combine context and question into a single 'query' key
        input_data = {"query": user_input}
        response = qa_chain.run(input_data)
        return response
    except Exception as e:
        return f"Error: {e}"

# %%
# Run the agent if qa_chain is successfully created
if qa_chain:
    while True:
        user_input = input("Ask a question (or type 'exit' to quit): ")
        if user_input.lower() == 'exit':
            break
        response = run_agent(user_input)
        print("Answer:", response)
else:
    print("QA chain was not created successfully, so the agent will not run.")
# Out:
# Ask a question (or type 'exit' to quit): ihone 13 details
# Answer: Let's talk about iPhone 13 details!
#
# I need you to be a little more specific about what kind of details you want.
#
# For example, do you want to know about:
#
# * **Technical specifications:** processor, RAM, storage options, cameras etc.?
# * **Design features:** size, weight, colors, materials?
# * **Performance and battery life:** how it handles demanding apps, how long the battery lasts?
# * **Availability and pricing:** release date, where to buy, cost?
#
# Tell me what you're curious about, and I can give you more detailed answers! 😄
#
# Ask a question (or type 'exit' to quit): exit

# %%
#UI Implementation
# Read the file to check its contents
with open("app.py", "r") as file:
    content = file.read()

print(content)
# Out:
# # Define the code as a string
# streamlit_code = """
# import streamlit as st
# from langchain_community.embeddings.ollama import OllamaEmbeddings
# from langchain.vectorstores import FAISS
# from langchain.chains import RetrievalQA
# from langchain_community.llms import Ollama
# from langchain_community.document_loaders import PyPDFLoader
#
# # Initialize the components (assuming you've set them up in your notebook)
# def setup_components():
#     embedding_model = OllamaEmbeddings()
#     return embedding_model
#
# st.title("Document Retrieval System")
#
# uploaded_file = st.file_uploader("Upload a PDF document", type="pdf")
# if uploaded_file:
#     # Load and process the document
#     loader = PyPDFLoader(uploaded_file)
#     documents = loader.load()
#     st.write(f"Loaded {len(documents)} pages.")
#
#     # Set up embeddings and vectorstore
#     embedding_model = setup_components()
#     vectorstore = FAISS.from_documents(documents, embedding_model)
#
#     st.write("Documents processed and vector store created.")
#
#     # Add a text input for querying the documents
#     query = st.text_input("Enter your query")
#     if query:
#         # Run the retrieval and display the result
#         chain = RetrievalQA.from_chain_type(llm=Ollama(), chain_type="stuff", vectorstore=vectorstore)
#         response = chain.run(query)
#         st.write(f"Response: {response}")
# """
#
# # Write the code to a text file
# with open("app.py", "w") as file:
#     file.write(streamlit_code)

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\mugdhi saxena\anaconda3\lib\site-packages (1.24.1)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Collecting packaging<24,>=14.1 (from streamlit)
#   Obtaining dependency information for packaging<24,>=14.1 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (0.9)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pandas<3,>=0.25->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (8.0.4)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (5.7.1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (6.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit) (4.0.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (1.5.6)
# Requirement already satisfied: psutil in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (23.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck<1,>=0.1.dev5->streamlit) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck<1,>=0.1.dev5->streamlit) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.11.0->streamlit) (0.1.0)
# Requirement already satisfied: backcall in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: entrypoints in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: executing in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.2)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# Successfully installed packaging-23.2

# %%
# !pip install --upgrade streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\mugdhi saxena\anaconda3\lib\site-packages (1.24.1)
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/b0/68/cf905fd2db4a84dc9b46803512b9765a3e9a6dfaa378a67c8db910c44ab3/streamlit-1.37.1-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.37.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.37.1-py2.py3-none-any.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB 1.4 MB/s eta 0:00:07
#     --------------------------------------- 0.2/8.7 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/8.7 MB 3.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/8.7 MB 4.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/8.7 MB 2.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/8.7 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/8.7 MB 3.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.7 MB 3.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/8.7 MB 3.7 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.7 MB 3.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.7 MB 4.1 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.7 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.2/8.7 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.7 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.7/8.7 MB 4.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.7 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.6/8.7 MB 4.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/8.7 MB 4.5 MB/s eta 0:00:02
#    ------------------ --------------------- 4.1/8.7 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 4.3/8.7 MB 4.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.6/8.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.8/8.7 MB 4.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.1/8.7 MB 4.6 MB/s eta 0:00:01
#    ------------------------ --------------- 5.4/8.7 MB 4.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.7/8.7 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.9/8.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.2/8.7 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.5/8.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.7 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 7.0/8.7 MB 5.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.4/8.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.8/8.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  8.5/8.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 5.1 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.9 MB 7.0 MB/s eta 0:00:01
#    -- ------------------------------------- 0.4/6.9 MB 6.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/6.9 MB 6.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.1/6.9 MB 6.3 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.9 MB 7.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.9 MB 6.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.9 MB 6.1 MB/s eta 0:00:01
#    ------------ --------------------------- 2.2/6.9 MB 6.5 MB/s eta 0:00:01
#    --------------- ------------------------ 2.6/6.9 MB 6.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/6.9 MB 6.5 MB/s eta 0:00:01
#    ------------------- -------------------- 3.3/6.9 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.6/6.9 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.0/6.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 4.4/6.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.9/6.9 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/6.9 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/6.9 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/6.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/6.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.4/6.9 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
#   Attempting uninstall: pydeck
#     Found existing installation: pydeck 0.7.1
#     Uninstalling pydeck-0.7.1:
#       Successfully uninstalled pydeck-0.7.1
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.24.1
#     Uninstalling streamlit-1.24.1:
#       Successfully uninstalled streamlit-1.24.1
# Successfully installed pydeck-0.9.1 streamlit-1.37.1

# %%
# !streamlit --version
# Out:
# Streamlit, version 1.37.1

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2Note: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for PyPDF2 from https://files.pythonhosted.org/packages/8e/5e/c86a5643653825d3c913719e788e41386bee415c2b87b4f955432f2de6b2/pypdf2-3.0.1-py3-none-any.whl.metadata
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/232.6 kB ? eta -:--:--
#    ---------------------------------------- 232.6/232.6 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# !streamlit run app3.py
# Out:
# ^C

# %%
pip install chainlit
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Mugdhi Saxena\\anaconda3\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting chainlit
#   Obtaining dependency information for chainlit from https://files.pythonhosted.org/packages/f8/db/ed38770febc1355441dad14137b4f06cd7f81f5bda48411a614f6a3c85b5/chainlit-1.1.402-py3-none-any.whl.metadata
#   Downloading chainlit-1.1.402-py3-none-any.whl.metadata (6.3 kB)
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit)
#   Obtaining dependency information for aiofiles<24.0.0,>=23.1.0 from https://files.pythonhosted.org/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl.metadata
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting asyncer<0.0.3,>=0.0.2 (from chainlit)
#   Obtaining dependency information for asyncer<0.0.3,>=0.0.2 from https://files.pythonhosted.org/packages/01/61/92a12d4a53f4b88178c36209188ba2478ca51862210edb5d22c9236a9c34/asyncer-0.0.2-py3-none-any.whl.metadata
#   Downloading asyncer-0.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting click<9.0.0,>=8.1.3 (from chainlit)
#   Obtaining dependency information for click<9.0.0,>=8.1.3 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dataclasses_json<0.6.0,>=0.5.7 (from chainlit)
#   Obtaining dependency information for dataclasses_json<0.6.0,>=0.5.7 from https://files.pythonhosted.org/packages/97/5f/e7cc90f36152810cab08b6c9c1125e8bcb9d76f8b3018d101b5f877b386c/dataclasses_json-0.5.14-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting fastapi<0.111.0,>=0.110.1 (from chainlit)
#   Obtaining dependency information for fastapi<0.111.0,>=0.110.1 from https://files.pythonhosted.org/packages/1d/d1/5958526c3bdbed74f88bf69b86506db5b25a600207f0f688473667690de6/fastapi-0.110.3-py3-none-any.whl.metadata
#   Downloading fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit)
#   Obtaining dependency information for filetype<2.0.0,>=1.2.0 from https://files.pythonhosted.org/packages/18/79/1b8fa1bb3568781e84c9200f951c735f3f157429f44be0495da55894d620/filetype-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.27.0)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit)
#   Obtaining dependency information for lazify<0.5.0,>=0.4.0 from https://files.pythonhosted.org/packages/03/a5/866b44697cee47d1cae429ed370281d937ad4439f71af82a6baaa139d26a/Lazify-0.4.0-py2.py3-none-any.whl.metadata
#   Downloading Lazify-0.4.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting literalai==0.0.607 (from chainlit)
#   Downloading literalai-0.0.607.tar.gz (49 kB)
#      ---------------------------------------- 0.0/49.7 kB ? eta -:--:--
#      ---------------------------------------- 49.7/49.7 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.5.6)
# Collecting numpy<2.0,>=1.26 (from chainlit)
#   Obtaining dependency information for numpy<2.0,>=1.26 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24.0,>=23.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.8.2)
# Collecting pyjwt<3.0.0,>=2.8.0 (from chainlit)
#   Obtaining dependency information for pyjwt<3.0.0,>=2.8.0 from https://files.pythonhosted.org/packages/79/84/0fdf9b18ba31d69877bd39c9cd6052b47f3761e9910c15de788e519f079f/PyJWT-2.9.0-py3-none-any.whl.metadata
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from chainlit)
#   Obtaining dependency information for python-dotenv<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.0.9)
# Collecting python-socketio<6.0.0,>=5.11.0 (from chainlit)
#   Obtaining dependency information for python-socketio<6.0.0,>=5.11.0 from https://files.pythonhosted.org/packages/e9/59/5ee858d5736594d75385b9a8c0f65af6eca5da2b359ed3fb6a7486526399/python_socketio-5.11.3-py3-none-any.whl.metadata
#   Downloading python_socketio-5.11.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.37.2)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit)
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tomli<3.0.0,>=2.0.1 (from chainlit)
#   Obtaining dependency information for tomli<3.0.0,>=2.0.1 from https://files.pythonhosted.org/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl.metadata
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting uptrace<2.0.0,>=1.22.0 (from chainlit)
#   Obtaining dependency information for uptrace<2.0.0,>=1.22.0 from https://files.pythonhosted.org/packages/77/43/cb8681716ffb025ca376c5994c6fb300a08cbb7d48a3346e2a2cf0b486e5/uptrace-1.26.0-py3-none-any.whl.metadata
#   Downloading uptrace-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting uvicorn<0.26.0,>=0.25.0 (from chainlit)
#   Obtaining dependency information for uvicorn<0.26.0,>=0.25.0 from https://files.pythonhosted.org/packages/26/59/fddd9df489fe27f492cc97626e03663fb3b9b6ef7ce8597a7cdc5f2cbbad/uvicorn-0.25.0-py3-none-any.whl.metadata
#   Downloading uvicorn-0.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting watchfiles<0.21.0,>=0.20.0 (from chainlit)
#   Obtaining dependency information for watchfiles<0.21.0,>=0.20.0 from https://files.pythonhosted.org/packages/87/79/098b1b1fcb6de16149d23283a2ab5dadce6a06b864e7a182d231f57a1f9e/watchfiles-0.20.0-cp37-abi3-win_amd64.whl.metadata
#   Downloading watchfiles-0.20.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting chevron>=0.14.0 (from literalai==0.0.607->chainlit)
#   Obtaining dependency information for chevron>=0.14.0 from https://files.pythonhosted.org/packages/52/93/342cc62a70ab727e093ed98e02a725d85b746345f05d2b5e5034649f4ec8/chevron-0.14.0-py3-none-any.whl.metadata
#   Downloading chevron-0.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from asyncer<0.0.3,>=0.0.2->chainlit) (3.5.0)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->chainlit) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from fastapi<0.111.0,>=0.110.1->chainlit) (4.12.2)
# Requirement already satisfied: certifi in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.0.5)
# Requirement already satisfied: idna in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (3.4)
# Requirement already satisfied: sniffio in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->chainlit) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (2.20.1)
# Collecting bidict>=0.21.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for bidict>=0.21.0 from https://files.pythonhosted.org/packages/99/37/e8730c3587a65eb5645d4aba2d27aae48e8003614d6aaf15dda67f702f1f/bidict-0.23.1-py3-none-any.whl.metadata
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.8.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for python-engineio>=4.8.0 from https://files.pythonhosted.org/packages/ad/38/4642c75241686c9cf05d23c50b9ffbd760507292f12fdfb04adc2ab5d34a/python_engineio-4.9.1-py3-none-any.whl.metadata
#   Downloading python_engineio-4.9.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-api~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-api~=1.26 from https://files.pythonhosted.org/packages/e3/a7/6322d1d7a1fb926e8b99208c27730f21217da2f1e0e11dab48a78a0427a4/opentelemetry_api-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp~=1.26 from https://files.pythonhosted.org/packages/87/71/b9221af6af61213c522401b5f46a5eaa41d8dd7daeb0740dc5604f5c3980/opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation~=0.47b0 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-instrumentation~=0.47b0 from https://files.pythonhosted.org/packages/1f/6a/be31a84ddd13e9018fcca6885e4710f227eb0fd06eda1896da67287faa2e/opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-sdk~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-sdk~=1.26 from https://files.pythonhosted.org/packages/92/f1/a9b550d0f9c049653dd2eab45cecf8fe4baa9795ed143d87834056ffabaf/opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for deprecated>=1.2.6 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (6.0.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.26.0 (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-grpc==1.26.0 from https://files.pythonhosted.org/packages/4d/0c/e4473692fec8076008c7926dfcef7223fc6d2785f04ad9d8402347a4eba9/opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.26.0 (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-http==1.26.0 from https://files.pythonhosted.org/packages/cf/d3/0b7217b61903249035d219fbe93a8558287f86aead340c7b2dc1226b8ad4/opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for googleapis-common-protos~=1.52 from https://files.pythonhosted.org/packages/02/48/87422ff1bddcae677fb6f58c97f5cfc613304a5e8ce2c3662760199c0a84/googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.64.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-common==1.26.0 from https://files.pythonhosted.org/packages/25/2f/0f7e0a73fd901c9abc6ea680d7f19a803dac830c450f21e1123d3a3ec488/opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-proto==1.26.0 from https://files.pythonhosted.org/packages/15/f4/66a3892eea913cded9bac0fdd3fb1a412fa2da8eb50014ec87a52648444a/opentelemetry_proto-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_proto-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests~=2.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.31.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.20.3)
# Requirement already satisfied: setuptools>=16.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (1.14.1)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-sdk~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.47b0 from https://files.pythonhosted.org/packages/00/c2/ca5cef8e4cd8eec5a95deed95ec3f6005e499fd9d17ca08731ced03a6921/opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for simple-websocket>=0.10.0 from https://files.pythonhosted.org/packages/6d/ea/288a8ac1d9551354488ff60c0ac6a76acc3b6b60f0460ac1944c75e240da/simple_websocket-1.0.0-py3-none-any.whl.metadata
#   Downloading simple_websocket-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.11.0)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for wsproto from https://files.pythonhosted.org/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl.metadata
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.2.2)
# Downloading chainlit-1.1.402-py3-none-any.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.7/4.3 MB 8.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.1/4.3 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.3 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 10.2 MB/s eta 0:00:01
#    -------------------------- ------------- 2.8/4.3 MB 10.5 MB/s eta 0:00:01
#    -------------------------------- ------- 3.5/4.3 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 4.0/4.3 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  4.3/4.3 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 9.8 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/91.8 kB ? eta -:--:--
#    ---------------------------------------- 91.8/91.8 kB ? eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.6/15.8 MB 19.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.3/15.8 MB 20.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.9/15.8 MB 17.1 MB/s eta 0:00:01
#    ------ --------------------------------- 2.6/15.8 MB 16.6 MB/s eta 0:00:01
#    -------- ------------------------------- 3.2/15.8 MB 16.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.0/15.8 MB 17.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.8/15.8 MB 17.0 MB/s eta 0:00:01
#    -------------- ------------------------- 5.5/15.8 MB 16.1 MB/s eta 0:00:01
#    --------------- ------------------------ 6.3/15.8 MB 16.8 MB/s eta 0:00:01
#    ------------------ --------------------- 7.2/15.8 MB 17.1 MB/s eta 0:00:01
#    -------------------- ------------------- 8.1/15.8 MB 16.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.7/15.8 MB 16.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/15.8 MB 16.7 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.8 MB 16.4 MB/s eta 0:00:01
#    --------------------------- ------------ 10.8/15.8 MB 16.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.4/15.8 MB 16.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 16.4 MB/s eta 0:00:01
#    -------------------------------- ------- 12.9/15.8 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.8 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.8 MB 16.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 15.6 MB/s eta 0:00:00
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_socketio-5.11.3-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.2 kB ? eta -:--:--
#    ---------------------------------------- 76.2/76.2 kB ? eta 0:00:00
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading uptrace-1.26.0-py3-none-any.whl (8.6 kB)
# Downloading uvicorn-0.25.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.3 kB ? eta -:--:--
#    ---------------------------------------- 60.3/60.3 kB ? eta 0:00:00
# Downloading watchfiles-0.20.0-cp37-abi3-win_amd64.whl (276 kB)
#    ---------------------------------------- 0.0/276.7 kB ? eta -:--:--
#    --------------------------------------- 276.7/276.7 kB 16.7 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#    ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.26.0-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.5 kB ? eta -:--:--
#    ---------------------------------------- 52.5/52.5 kB ? eta 0:00:00
# Downloading opentelemetry_instrumentation-0.47b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    ---------------------------------------- 109.5/109.5 kB 6.6 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.0 kB ? eta -:--:--
#    ---------------------------------------- 138.0/138.0 kB ? eta 0:00:00
# Downloading python_engineio-4.9.1-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#    ---------------------------------------- 57.7/57.7 kB ? eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#    ---------------------------------------- 0.0/220.0 kB ? eta -:--:--
#    --------------------------------------- 220.0/220.0 kB 14.0 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: literalai, syncer
#   Building wheel for literalai (setup.py): started
#   Building wheel for literalai (setup.py): finished with status 'done'
#   Created wheel for literalai: filename=literalai-0.0.607-py3-none-any.whl size=64154 sha256=3ef0c4c4661dd2956ef7c41ba3615649f7e2cf6ff38529665ce76e7f6ab41319
#   Stored in directory: c:\users\mugdhi saxena\appdata\local\pip\cache\wheels\18\cc\75\54d490970c897bbdbc6a937041e7c30399cf6b5b3d437beb06
#   Building wheel for syncer (setup.py): started
#   Building wheel for syncer (setup.py): finished with status 'done'
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3452 sha256=3e1bc6ccb76c80e3068fb5b2c76ac219ae007094adfc4445ccdbd0880de97868
#   Stored in directory: c:\users\mugdhi saxena\appdata\local\pip\cache\wheels\fa\a7\d4\9253c7f0256e67e3ff75d4c095c076a3882e319728e94bc6a1
# Successfully built literalai syncer
# Installing collected packages: syncer, lazify, filetype, chevron, wsproto, tomli, python-dotenv, pyjwt, opentelemetry-proto, numpy, googleapis-common-protos, deprecated, click, bidict, aiofiles, watchfiles, uvicorn, simple-websocket, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, dataclasses_json, asyncer, python-engineio, opentelemetry-semantic-conventions, opentelemetry-instrumentation, literalai, fastapi, python-socketio, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-exporter-otlp, uptrace, chainlit
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.21.0
#     Uninstalling python-dotenv-0.21.0:
#       Successfully uninstalled python-dotenv-0.21.0
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.4.0
#     Uninstalling PyJWT-2.4.0:
#       Successfully uninstalled PyJWT-2.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Collecting chainlit
#   Obtaining dependency information for chainlit from https://files.pythonhosted.org/packages/f8/db/ed38770febc1355441dad14137b4f06cd7f81f5bda48411a614f6a3c85b5/chainlit-1.1.402-py3-none-any.whl.metadata
#   Using cached chainlit-1.1.402-py3-none-any.whl.metadata (6.3 kB)
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit)
#   Obtaining dependency information for aiofiles<24.0.0,>=23.1.0 from https://files.pythonhosted.org/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl.metadata
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting asyncer<0.0.3,>=0.0.2 (from chainlit)
#   Obtaining dependency information for asyncer<0.0.3,>=0.0.2 from https://files.pythonhosted.org/packages/01/61/92a12d4a53f4b88178c36209188ba2478ca51862210edb5d22c9236a9c34/asyncer-0.0.2-py3-none-any.whl.metadata
#   Using cached asyncer-0.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting click<9.0.0,>=8.1.3 (from chainlit)
#   Obtaining dependency information for click<9.0.0,>=8.1.3 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dataclasses_json<0.6.0,>=0.5.7 (from chainlit)
#   Obtaining dependency information for dataclasses_json<0.6.0,>=0.5.7 from https://files.pythonhosted.org/packages/97/5f/e7cc90f36152810cab08b6c9c1125e8bcb9d76f8b3018d101b5f877b386c/dataclasses_json-0.5.14-py3-none-any.whl.metadata
#   Using cached dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting fastapi<0.111.0,>=0.110.1 (from chainlit)
#   Obtaining dependency information for fastapi<0.111.0,>=0.110.1 from https://files.pythonhosted.org/packages/1d/d1/5958526c3bdbed74f88bf69b86506db5b25a600207f0f688473667690de6/fastapi-0.110.3-py3-none-any.whl.metadata
#   Using cached fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit)
#   Obtaining dependency information for filetype<2.0.0,>=1.2.0 from https://files.pythonhosted.org/packages/18/79/1b8fa1bb3568781e84c9200f951c735f3f157429f44be0495da55894d620/filetype-1.2.0-py2.py3-none-any.whl.metadata
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.27.0)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit)
#   Obtaining dependency information for lazify<0.5.0,>=0.4.0 from https://files.pythonhosted.org/packages/03/a5/866b44697cee47d1cae429ed370281d937ad4439f71af82a6baaa139d26a/Lazify-0.4.0-py2.py3-none-any.whl.metadata
#   Using cached Lazify-0.4.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting literalai==0.0.607 (from chainlit)
#   Using cached literalai-0.0.607.tar.gz (49 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.5.6)
# Collecting numpy<2.0,>=1.26 (from chainlit)
#   Obtaining dependency information for numpy<2.0,>=1.26 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: packaging<24.0,>=23.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.8.2)
# Collecting pyjwt<3.0.0,>=2.8.0 (from chainlit)
#   Obtaining dependency information for pyjwt<3.0.0,>=2.8.0 from https://files.pythonhosted.org/packages/79/84/0fdf9b18ba31d69877bd39c9cd6052b47f3761e9910c15de788e519f079f/PyJWT-2.9.0-py3-none-any.whl.metadata
#   Using cached PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from chainlit)
#   Obtaining dependency information for python-dotenv<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.0.9)
# Collecting python-socketio<6.0.0,>=5.11.0 (from chainlit)
#   Obtaining dependency information for python-socketio<6.0.0,>=5.11.0 from https://files.pythonhosted.org/packages/e9/59/5ee858d5736594d75385b9a8c0f65af6eca5da2b359ed3fb6a7486526399/python_socketio-5.11.3-py3-none-any.whl.metadata
#   Using cached python_socketio-5.11.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.37.2)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit)
#   Using cached syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tomli<3.0.0,>=2.0.1 (from chainlit)
#   Obtaining dependency information for tomli<3.0.0,>=2.0.1 from https://files.pythonhosted.org/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl.metadata
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting uptrace<2.0.0,>=1.22.0 (from chainlit)
#   Obtaining dependency information for uptrace<2.0.0,>=1.22.0 from https://files.pythonhosted.org/packages/77/43/cb8681716ffb025ca376c5994c6fb300a08cbb7d48a3346e2a2cf0b486e5/uptrace-1.26.0-py3-none-any.whl.metadata
#   Using cached uptrace-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting uvicorn<0.26.0,>=0.25.0 (from chainlit)
#   Obtaining dependency information for uvicorn<0.26.0,>=0.25.0 from https://files.pythonhosted.org/packages/26/59/fddd9df489fe27f492cc97626e03663fb3b9b6ef7ce8597a7cdc5f2cbbad/uvicorn-0.25.0-py3-none-any.whl.metadata
#   Using cached uvicorn-0.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting watchfiles<0.21.0,>=0.20.0 (from chainlit)
#   Obtaining dependency information for watchfiles<0.21.0,>=0.20.0 from https://files.pythonhosted.org/packages/87/79/098b1b1fcb6de16149d23283a2ab5dadce6a06b864e7a182d231f57a1f9e/watchfiles-0.20.0-cp37-abi3-win_amd64.whl.metadata
#   Using cached watchfiles-0.20.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting chevron>=0.14.0 (from literalai==0.0.607->chainlit)
#   Obtaining dependency information for chevron>=0.14.0 from https://files.pythonhosted.org/packages/52/93/342cc62a70ab727e093ed98e02a725d85b746345f05d2b5e5034649f4ec8/chevron-0.14.0-py3-none-any.whl.metadata
#   Using cached chevron-0.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from asyncer<0.0.3,>=0.0.2->chainlit) (3.5.0)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->chainlit) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from fastapi<0.111.0,>=0.110.1->chainlit) (4.12.2)
# Requirement already satisfied: certifi in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.0.5)
# Requirement already satisfied: idna in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (3.4)
# Requirement already satisfied: sniffio in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->chainlit) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (2.20.1)
# Collecting bidict>=0.21.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for bidict>=0.21.0 from https://files.pythonhosted.org/packages/99/37/e8730c3587a65eb5645d4aba2d27aae48e8003614d6aaf15dda67f702f1f/bidict-0.23.1-py3-none-any.whl.metadata
#   Using cached bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.8.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for python-engineio>=4.8.0 from https://files.pythonhosted.org/packages/ad/38/4642c75241686c9cf05d23c50b9ffbd760507292f12fdfb04adc2ab5d34a/python_engineio-4.9.1-py3-none-any.whl.metadata
#   Using cached python_engineio-4.9.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-api~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-api~=1.26 from https://files.pythonhosted.org/packages/e3/a7/6322d1d7a1fb926e8b99208c27730f21217da2f1e0e11dab48a78a0427a4/opentelemetry_api-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp~=1.26 from https://files.pythonhosted.org/packages/87/71/b9221af6af61213c522401b5f46a5eaa41d8dd7daeb0740dc5604f5c3980/opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation~=0.47b0 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-instrumentation~=0.47b0 from https://files.pythonhosted.org/packages/1f/6a/be31a84ddd13e9018fcca6885e4710f227eb0fd06eda1896da67287faa2e/opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata
#   Using cached opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-sdk~=1.26 (from uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-sdk~=1.26 from https://files.pythonhosted.org/packages/92/f1/a9b550d0f9c049653dd2eab45cecf8fe4baa9795ed143d87834056ffabaf/opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for deprecated>=1.2.6 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (6.0.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.26.0 (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-grpc==1.26.0 from https://files.pythonhosted.org/packages/4d/0c/e4473692fec8076008c7926dfcef7223fc6d2785f04ad9d8402347a4eba9/opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.26.0 (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-http==1.26.0 from https://files.pythonhosted.org/packages/cf/d3/0b7217b61903249035d219fbe93a8558287f86aead340c7b2dc1226b8ad4/opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for googleapis-common-protos~=1.52 from https://files.pythonhosted.org/packages/02/48/87422ff1bddcae677fb6f58c97f5cfc613304a5e8ce2c3662760199c0a84/googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.64.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-common==1.26.0 from https://files.pythonhosted.org/packages/25/2f/0f7e0a73fd901c9abc6ea680d7f19a803dac830c450f21e1123d3a3ec488/opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-proto==1.26.0 from https://files.pythonhosted.org/packages/15/f4/66a3892eea913cded9bac0fdd3fb1a412fa2da8eb50014ec87a52648444a/opentelemetry_proto-1.26.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_proto-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests~=2.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.31.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.20.3)
# Requirement already satisfied: setuptools>=16.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (1.14.1)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-sdk~=1.26->uptrace<2.0.0,>=1.22.0->chainlit)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.47b0 from https://files.pythonhosted.org/packages/00/c2/ca5cef8e4cd8eec5a95deed95ec3f6005e499fd9d17ca08731ced03a6921/opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata
#   Using cached opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for simple-websocket>=0.10.0 from https://files.pythonhosted.org/packages/6d/ea/288a8ac1d9551354488ff60c0ac6a76acc3b6b60f0460ac1944c75e240da/simple_websocket-1.0.0-py3-none-any.whl.metadata
#   Using cached simple_websocket-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.11.0)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Obtaining dependency information for wsproto from https://files.pythonhosted.org/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl.metadata
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.2.2)
# Using cached chainlit-1.1.402-py3-none-any.whl (4.3 MB)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Using cached asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Using cached fastapi-0.110.3-py3-none-any.whl (91 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached python_socketio-5.11.3-py3-none-any.whl (76 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Using cached uptrace-1.26.0-py3-none-any.whl (8.6 kB)
# Using cached uvicorn-0.25.0-py3-none-any.whl (60 kB)
# Using cached watchfiles-0.20.0-cp37-abi3-win_amd64.whl (276 kB)
# Using cached bidict-0.23.1-py3-none-any.whl (32 kB)
# Using cached chevron-0.14.0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
# Using cached opentelemetry_exporter_otlp-1.26.0-py3-none-any.whl (7.0 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.26.0-py3-none-any.whl (52 kB)
# Using cached opentelemetry_instrumentation-0.47b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
# Using cached opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
# Using cached python_engineio-4.9.1-py3-none-any.whl (57 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: literalai, syncer
#   Building wheel for literalai (setup.py): started
#   Building wheel for literalai (setup.py): finished with status 'done'
#   Created wheel for literalai: filename=literalai-0.0.607-py3-none-any.whl size=64154 sha256=71f8ad10deee5ff4ac91b2d9b17b28e2b75d791134fc675458788599945dd0e6
#   Stored in directory: c:\users\mugdhi saxena\appdata\local\pip\cache\wheels\18\cc\75\54d490970c897bbdbc6a937041e7c30399cf6b5b3d437beb06
#   Building wheel for syncer (setup.py): started
#   Building wheel for syncer (setup.py): finished with status 'done'
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3452 sha256=1ee3154ed77d9708bcfe169ddf6ce943a802cae54d1b29ac4d11448a9ccebc28
#   Stored in directory: c:\users\mugdhi saxena\appdata\local\pip\cache\wheels\fa\a7\d4\9253c7f0256e67e3ff75d4c095c076a3882e319728e94bc6a1
# Successfully built literalai syncer
# Installing collected packages: syncer, lazify, filetype, chevron, wsproto, tomli, python-dotenv, pyjwt, opentelemetry-proto, numpy, googleapis-common-protos, deprecated, click, bidict, aiofiles, watchfiles, uvicorn, simple-websocket, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, dataclasses_json, asyncer, python-engineio, opentelemetry-semantic-conventions, opentelemetry-instrumentation, literalai, fastapi, python-socketio, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-exporter-otlp, uptrace, chainlit
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.0.1
#     Uninstalling python-dotenv-1.0.1:
#       Successfully uninstalled python-dotenv-1.0.1
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.9.0
#     Uninstalling PyJWT-2.9.0:
#       Successfully uninstalled PyJWT-2.9.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 22.1.0
#     Uninstalling aiofiles-22.1.0:
#       Successfully uninstalled aiofiles-22.1.0
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.30.6
#     Uninstalling uvicorn-0.30.6:
#       Successfully uninstalled uvicorn-0.30.6
#   Attempting uninstall: dataclasses_json
#     Found existing installation: dataclasses-json 0.6.7
#     Uninstalling dataclasses-json-0.6.7:
#       Successfully uninstalled dataclasses-json-0.6.7
# Successfully installed aiofiles-23.2.1 asyncer-0.0.2 bidict-0.23.1 chainlit-1.1.402 chevron-0.14.0 click-8.1.7 dataclasses_json-0.5.14 deprecated-1.2.14 fastapi-0.110.3 filetype-1.2.0 googleapis-common-protos-1.63.2 lazify-0.4.0 literalai-0.0.607 numpy-1.26.4 opentelemetry-api-1.26.0 opentelemetry-exporter-otlp-1.26.0 opentelemetry-exporter-otlp-proto-common-1.26.0 opentelemetry-exporter-otlp-proto-grpc-1.26.0 opentelemetry-exporter-otlp-proto-http-1.26.0 opentelemetry-instrumentation-0.47b0 opentelemetry-proto-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 pyjwt-2.9.0 python-dotenv-1.0.1 python-engineio-4.9.1 python-socketio-5.11.3 simple-websocket-1.0.0 syncer-2.0.3 tomli-2.0.1 uptrace-1.26.0 uvicorn-0.25.0 watchfiles-0.20.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\~umpy-1.24.3.dist-info due to invalid metadata entry 'name'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.8.2 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# ypy-websocket 0.8.2 requires aiofiles<23,>=22.1.0, but you have aiofiles 23.2.1 which is incompatible.

# %%
# !python app4.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Mugdhi Saxena\cognizant\app4.py", line 10, in <module>
#     cl.main()  # This may replace cl.run(), depending on the latest API
#     ^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\chainlit\utils.py", line 70, in __getattr__
#     module_path = registry[name]
#                   ~~~~~~~~^^^^^^
# KeyError: 'main'

# %%
pip install --upgrade chainlit
# Out:
# Requirement already satisfied: chainlit in c:\users\mugdhi saxena\anaconda3\lib\site-packages (1.1.402)
# Requirement already satisfied: aiofiles<24.0.0,>=23.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (23.2.1)
# Requirement already satisfied: asyncer<0.0.3,>=0.0.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.0.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (8.1.7)
# Requirement already satisfied: dataclasses_json<0.6.0,>=0.5.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.5.14)
# Requirement already satisfied: fastapi<0.111.0,>=0.110.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.110.3)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.2.0)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.27.0)
# Requirement already satisfied: lazify<0.5.0,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.4.0)
# Requirement already satisfied: literalai==0.0.607 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.0.607)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.5.6)
# Requirement already satisfied: numpy<2.0,>=1.26 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.26.4)
# Requirement already satisfied: packaging<24.0,>=23.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.8.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.9.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.0.1)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.0.9)
# Requirement already satisfied: python-socketio<6.0.0,>=5.11.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (5.11.3)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.37.2)
# Requirement already satisfied: syncer<3.0.0,>=2.0.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.0.3)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (2.0.1)
# Requirement already satisfied: uptrace<2.0.0,>=1.22.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (1.26.0)
# Requirement already satisfied: uvicorn<0.26.0,>=0.25.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.25.0)
# Requirement already satisfied: watchfiles<0.21.0,>=0.20.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from chainlit) (0.20.0)
# Requirement already satisfied: chevron>=0.14.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from literalai==0.0.607->chainlit) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from asyncer<0.0.3,>=0.0.2->chainlit) (3.5.0)
# Requirement already satisfied: colorama in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->chainlit) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from fastapi<0.111.0,>=0.110.1->chainlit) (4.12.2)
# Requirement already satisfied: certifi in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.0.5)
# Requirement already satisfied: idna in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (3.4)
# Requirement already satisfied: sniffio in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpx>=0.23.0->chainlit) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->chainlit) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->chainlit) (2.20.1)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from python-socketio<6.0.0,>=5.11.0->chainlit) (0.23.1)
# Requirement already satisfied: python-engineio>=4.8.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from python-socketio<6.0.0,>=5.11.0->chainlit) (4.9.1)
# Requirement already satisfied: opentelemetry-api~=1.26 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp~=1.26 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation~=0.47b0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (0.47b0)
# Requirement already satisfied: opentelemetry-sdk~=1.26 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (6.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.26.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.26.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.63.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.64.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (1.26.0)
# Requirement already satisfied: requests~=2.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.31.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.20.3)
# Requirement already satisfied: setuptools>=16.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-instrumentation~=0.47b0->uptrace<2.0.0,>=1.22.0->chainlit) (1.14.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (0.47b0)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit) (1.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (3.11.0)
# Requirement already satisfied: wsproto in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.26.0->opentelemetry-exporter-otlp~=1.26->uptrace<2.0.0,>=1.22.0->chainlit) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !chainlit run main.py
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Mugdhi Saxena\anaconda3\Scripts\chainlit.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\click\core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\click\core.py", line 1078, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\click\core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\click\core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\click\core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\chainlit\cli\__init__.py", line 201, in chainlit_run
#     run_chainlit(target)
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\chainlit\cli\__init__.py", line 66, in run_chainlit
#     load_module(config.run.module_name)
#   File "C:\Users\Mugdhi Saxena\anaconda3\Lib\site-packages\chainlit\config.py", line 419, in load_module
#     spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\Mugdhi Saxena\cognizant\main.py", line 9, in <module>
#     from langchain_community.docstores import InMemoryDocstore  # Updated import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'langchain_community.docstores'

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\mugdhi saxena\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.5.14)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.2.32)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (0.1.99)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain_community) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.13->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.30->langchain_community) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain_community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain_community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mugdhi saxena\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run app2.py
